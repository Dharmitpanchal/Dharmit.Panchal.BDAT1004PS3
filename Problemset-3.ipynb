# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# <h1>Question-1

# %%
users=pd.read_csv('D:\Dharmit\Georgian\Data Programming\Problem set-3\Que-1.txt',sep='|')

# %%
users.head()
# Out:
#    user_id  age gender  occupation zip_code
# 0        1   24      M  technician    85711
# 1        2   53      F       other    94043
# 2        3   23      M      writer    32067
# 3        4   24      M  technician    43537
# 4        5   33      F       other    15213

# %%
users[['occupation','age']].groupby('occupation').mean()
# Out:
#                      age
# occupation
# administrator  38.746835
# artist         31.392857
# doctor         43.571429
# educator       42.010526
# engineer       36.388060
# entertainment  29.222222
# executive      38.718750
# healthcare     41.562500
# homemaker      32.571429
# lawyer         36.750000
# librarian      40.000000
# marketing      37.615385
# none           26.555556
# other          34.523810
# programmer     33.121212
# retired        63.071429
# salesman       35.666667
# scientist      35.548387
# student        22.081633
# technician     33.148148
# writer         36.311111

# %%
ab=users.groupby(['occupation','gender']).gender.count()
cd=users.groupby('occupation').gender.count()
total=(ab/cd)*100
total.sort_values(ascending=False).xs('M',level=1)
# Out:
# occupation
# doctor           100.000000
# engineer          97.014925
# technician        96.296296
# retired           92.857143
# programmer        90.909091
# executive         90.625000
# scientist         90.322581
# entertainment     88.888889
# lawyer            83.333333
# salesman          75.000000
# educator          72.631579
# student           69.387755
# other             65.714286
# marketing         61.538462
# writer            57.777778
# none              55.555556
# administrator     54.430380
# artist            53.571429
# librarian         43.137255
# healthcare        31.250000
# homemaker         14.285714
# Name: gender, dtype: float64

# %%
users.groupby('occupation').age.agg(['min', 'max'])
# Out:
#                min  max
# occupation
# administrator   21   70
# artist          19   48
# doctor          28   64
# educator        23   63
# engineer        22   70
# entertainment   15   50
# executive       22   69
# healthcare      22   62
# homemaker       20   50
# lawyer          21   53
# librarian       23   69
# marketing       24   55
# none            11   55
# other           13   64
# programmer      20   63
# retired         51   73
# salesman        18   66
# scientist       23   55
# student          7   42
# technician      21   55
# writer          18   60

# %%
users.groupby(['occupation','gender'])['age'].mean()
# Out:
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# other          F         35.472222
# ...

# %%
gendernum = users.groupby(['occupation', 'gender']).agg({'gender': 'count'})
total= users.groupby(['occupation']).agg('count')
final=((gendernum/total) * 100).round(1)
final.loc[: , 'gender']
# Out:
# occupation     gender
# administrator  F          45.6
#                M          54.4
# artist         F          46.4
#                M          53.6
# doctor         M         100.0
# educator       F          27.4
#                M          72.6
# engineer       F           3.0
#                M          97.0
# entertainment  F          11.1
#                M          88.9
# executive      F           9.4
#                M          90.6
# healthcare     F          68.8
#                M          31.2
# homemaker      F          85.7
#                M          14.3
# lawyer         F          16.7
#                M          83.3
# librarian      F          56.9
#                M          43.1
# marketing      F          38.5
#                M          61.5
# none           F          44.4
#                M          55.6
# other          F          34.3
#                M          65.7
# programmer     F           9.1
#                M          90.9
# ...

# %% [markdown]
# <h1>Question-2

# %%
euro12=pd.read_csv('Euro.csv')

# %%
euro12.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %%
euro12['Goals']
# Out:
# 0      4
# 1      4
# 2      4
# 3      5
# 4      3
# 5     10
# 6      5
# 7      6
# 8      2
# 9      2
# 10     6
# 11     1
# 12     5
# 13    12
# 14     5
# 15     2
# Name: Goals, dtype: int64

# %%
euro12['Team'].nunique()
# Out:
# 16

# %%
len(euro12.columns)
# Out:
# 35

# %%
discipline=euro12[['Team','Red Cards','Yellow Cards']]
discipline
# Out:
#                    Team  Red Cards  Yellow Cards
# 0               Croatia          0             9
# 1        Czech Republic          0             7
# 2               Denmark          0             4
# 3               England          0             5
# 4                France          0             6
# 5               Germany          0             4
# 6                Greece          1             9
# 7                 Italy          0            16
# 8           Netherlands          0             5
# 9                Poland          1             7
# 10             Portugal          0            12
# 11  Republic of Ireland          1             6
# 12               Russia          0             6
# 13                Spain          0            11
# 14               Sweden          0             7
# 15              Ukraine          0             5

# %%
sorted=discipline.sort_values(by=['Red Cards','Yellow Cards'])
sorted
# Out:
#                    Team  Red Cards  Yellow Cards
# 2               Denmark          0             4
# 5               Germany          0             4
# 3               England          0             5
# 8           Netherlands          0             5
# 15              Ukraine          0             5
# 4                France          0             6
# 12               Russia          0             6
# 1        Czech Republic          0             7
# 14               Sweden          0             7
# 0               Croatia          0             9
# 13                Spain          0            11
# 10             Portugal          0            12
# 7                 Italy          0            16
# 11  Republic of Ireland          1             6
# 9                Poland          1             7
# 6                Greece          1             9

# %%
discipline.groupby('Team').mean()
# Out:
#                      Red Cards  Yellow Cards
# Team
# Croatia                      0             9
# Czech Republic               0             7
# Denmark                      0             4
# England                      0             5
# France                       0             6
# Germany                      0             4
# Greece                       1             9
# Italy                        0            16
# Netherlands                  0             5
# Poland                       1             7
# Portugal                     0            12
# Republic of Ireland          1             6
# Russia                       0             6
# Spain                        0            11
# Sweden                       0             7
# Ukraine                      0             5

# %%
more6goals=euro12[euro12.Goals>6]
more6goals
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %%
startwithg=euro12.loc[euro12['Team'].str.startswith('G')].copy()
startwithg
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %%
euro12.iloc[:, :7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
euro12.iloc[:,:-3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %%
rows=['England','Italy','Russia']
euro12[euro12.Team.isin(rows)]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 3   England      5               11                18             50.0%
# 7     Italy      6               34                45             43.0%
# 12   Russia      5                9                31             22.5%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 3             17.2%                          40             0              0
# 7              7.5%                         110             2              0
# 12            12.5%                          59             2              0
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 3                      0  ...          22                 88.1%         43
# 7                      0  ...          20                 74.1%        101
# 12                     0  ...          10                 77.0%         34
#
# ...

# %% [markdown]
# <h1>Question-3

# %%
s1=np.random.randint(1,4,size=(100))
s2=np.random.randint(1,3,size=(100))
s3=np.random.randint(10000,30000,size=(100))

# %%
q3=pd.DataFrame({'bedrs':s1,'bathrs':s2,'price_sqr_meter':s3})

# %%
q3.head()
# Out:
#    bedrs  bathrs  price_sqr_meter
# 0      3       2            21094
# 1      1       2            18190
# 2      1       2            25340
# 3      2       1            23912
# 4      2       2            14062

# %%
q3['bigcolumn']=('s1','s2','s3')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-112-adf157c84de3> in <module>
# ----> 1 q3['bigcolumn']=('s1','s2','s3')
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    3161         else:
#    3162             # set column
# -> 3163             self._set_item(key, value)
#    3164
#    3165     def _setitem_slice(self, key: slice, value):
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    3240         """
#    3241         self._ensure_valid_index(value)
# -> 3242         value = self._sanitize_column(key, value)
#    3243         NDFrame._set_item(self, key, value)
#    3244
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3897
#    3898             # turn me into an ndarray
# ...

# %%
q3.reindex('bigcolumn')

# %% [markdown]
# <h1>Question-4

# %%
data=pd.read_csv('wind.txt',sep=",")

# %%
data.head()
# Out:
#    Yr  Mo   Dy  Unnamed: 3  Unnamed: 4    RPT  Unnamed: 6  Unnamed: 7    VAL  \
# 0  61 NaN  1.0         NaN         1.0  15.04       14.96       13.17    NaN
# 1  61 NaN  1.0         NaN         2.0  14.71         NaN         NaN    NaN
# 2  61 NaN  1.0         NaN         3.0  18.50       16.88       12.33  10.13
# 3  61 NaN  1.0         NaN         4.0  10.58         NaN        6.63  11.75
# 4  61 NaN  1.0         NaN         5.0  13.33       13.25       11.42    NaN
#
#    Unnamed: 9  ...  MUL  Unnamed: 30  Unnamed: 31  CLO  Unnamed: 33  \
# 0        9.29  ...  NaN          NaN          NaN  NaN          NaN
# 1       10.83  ...  NaN          NaN          NaN  NaN          NaN
# 2       11.17  ...  NaN          NaN          NaN  NaN          NaN
# 3         NaN  ...  NaN          NaN          NaN  NaN          NaN
# 4        6.17  ...  NaN          NaN          NaN  NaN          NaN
#
#    Unnamed: 34  BEL  Unnamed: 36  Unnamed: 37  MAL
# ...

# %%
data=data.loc[:, ~data.columns.str.contains('^Unnamed')]
data
# Out:
#       Yr    Mo    Dy    RPT    VAL    ROS    KIL    SHA    BIR  DUB  CLA  MUL  \
# 0     61   NaN   1.0  15.04    NaN    NaN   9.87  10.83  15.04  NaN  NaN  NaN
# 1     61   NaN   1.0  14.71    NaN   6.50   7.67    NaN   9.67  NaN  NaN  NaN
# 2     61   NaN   1.0  18.50  10.13   6.17    NaN   8.50  12.75  NaN  NaN  NaN
# 3     61   NaN   1.0  10.58  11.75    NaN   2.88    NaN   5.83  NaN  NaN  NaN
# 4     61   NaN   1.0  13.33    NaN    NaN    NaN  10.34    NaN  NaN  NaN  NaN
# ...   ..   ...   ...    ...    ...    ...    ...    ...    ...  ...  ...  ...
# 6569  78  12.0  27.0  17.62  13.21  15.59  17.21    NaN    NaN  NaN  NaN  NaN
# 6570  78  12.0  28.0   5.46   5.00    NaN  16.25  21.79    NaN  NaN  NaN  NaN
# 6571  78  12.0  29.0  14.42    NaN  19.17  16.42    NaN    NaN  NaN  NaN  NaN
# 6572  78  12.0  30.0  21.29  12.75  18.08  12.12    NaN    NaN  NaN  NaN  NaN
# 6573  78  12.0  31.0  27.29  12.08  11.63  12.08    NaN    NaN  NaN  NaN  NaN
#
#       CLO  BEL  MAL
# ...

# %%
data.rename(columns={'Yr':'Year','Mo':'Month','Dy':'Day'},inplace=True)
data
# Out:
#       Year  Month   Day    RPT    VAL    ROS    KIL    SHA    BIR  DUB  CLA  \
# 0       61    NaN   1.0  15.04    NaN    NaN   9.87  10.83  15.04  NaN  NaN
# 1       61    NaN   1.0  14.71    NaN   6.50   7.67    NaN   9.67  NaN  NaN
# 2       61    NaN   1.0  18.50  10.13   6.17    NaN   8.50  12.75  NaN  NaN
# 3       61    NaN   1.0  10.58  11.75    NaN   2.88    NaN   5.83  NaN  NaN
# 4       61    NaN   1.0  13.33    NaN    NaN    NaN  10.34    NaN  NaN  NaN
# ...    ...    ...   ...    ...    ...    ...    ...    ...    ...  ...  ...
# 6569    78   12.0  27.0  17.62  13.21  15.59  17.21    NaN    NaN  NaN  NaN
# 6570    78   12.0  28.0   5.46   5.00    NaN  16.25  21.79    NaN  NaN  NaN
# 6571    78   12.0  29.0  14.42    NaN  19.17  16.42    NaN    NaN  NaN  NaN
# 6572    78   12.0  30.0  21.29  12.75  18.08  12.12    NaN    NaN  NaN  NaN
# 6573    78   12.0  31.0  27.29  12.08  11.63  12.08    NaN    NaN  NaN  NaN
#
#       MUL  CLO  BEL  MAL
# 0     NaN  NaN  NaN  NaN
# ...

# %%
data.drop(labels=[2061],axis=0,inplace=False)
# Out:
#       Year  Month   Day    RPT    VAL    ROS    KIL    SHA    BIR  DUB  CLA  \
# 0       61    NaN   1.0  15.04    NaN    NaN   9.87  10.83  15.04  NaN  NaN
# 1       61    NaN   1.0  14.71    NaN   6.50   7.67    NaN   9.67  NaN  NaN
# 2       61    NaN   1.0  18.50  10.13   6.17    NaN   8.50  12.75  NaN  NaN
# 3       61    NaN   1.0  10.58  11.75    NaN   2.88    NaN   5.83  NaN  NaN
# 4       61    NaN   1.0  13.33    NaN    NaN    NaN  10.34    NaN  NaN  NaN
# ...    ...    ...   ...    ...    ...    ...    ...    ...    ...  ...  ...
# 6569    78   12.0  27.0  17.62  13.21  15.59  17.21    NaN    NaN  NaN  NaN
# 6570    78   12.0  28.0   5.46   5.00    NaN  16.25  21.79    NaN  NaN  NaN
# 6571    78   12.0  29.0  14.42    NaN  19.17  16.42    NaN    NaN  NaN  NaN
# 6572    78   12.0  30.0  21.29  12.75  18.08  12.12    NaN    NaN  NaN  NaN
# 6573    78   12.0  31.0  27.29  12.08  11.63  12.08    NaN    NaN  NaN  NaN
#
#       MUL  CLO  BEL  MAL
# 0     NaN  NaN  NaN  NaN
# ...

# %%
data['Year']=pd.to_datetime(data['Year'])
data['Month']=pd.to_datetime(data['Month'])
data['Day']=pd.to_datetime(data['Day'])

# %%
data.dtypes
# Out:
# Year     datetime64[ns]
# Month    datetime64[ns]
# Day      datetime64[ns]
# RPT             float64
# VAL             float64
# ROS             float64
# KIL             float64
# SHA             float64
# BIR             float64
# DUB             float64
# CLA             float64
# MUL             float64
# CLO             float64
# BEL             float64
# MAL             float64
# dtype: object

# %%
data.isnull().sum()
# Out:
# Year        0
# Month    4918
# Day       486
# RPT      1625
# VAL      2432
# ROS      2152
# KIL      2331
# SHA      3204
# BIR      4065
# DUB      4416
# CLA      5590
# MUL      6574
# CLO      6574
# BEL      6574
# MAL      6574
# dtype: int64

# %%
data
# Out:
#                               Year                         Month  \
# 0    1970-01-01 00:00:00.000000061                           NaT
# 1    1970-01-01 00:00:00.000000061                           NaT
# 2    1970-01-01 00:00:00.000000061                           NaT
# 3    1970-01-01 00:00:00.000000061                           NaT
# 4    1970-01-01 00:00:00.000000061                           NaT
# ...                            ...                           ...
# 6569 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6570 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6571 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6572 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
# 6573 1970-01-01 00:00:00.000000078 1970-01-01 00:00:00.000000012
#
#                                Day    RPT    VAL    ROS    KIL    SHA    BIR  \
# 0    1970-01-01 00:00:00.000000001  15.04    NaN    NaN   9.87  10.83  15.04
# ...

# %%
data.notnull().sum()
# Out:
# Year     6574
# Month    1656
# Day      6088
# RPT      4949
# VAL      4142
# ROS      4422
# KIL      4243
# SHA      3370
# BIR      2509
# DUB      2158
# CLA       984
# MUL         0
# CLO         0
# BEL         0
# MAL         0
# dtype: int64

# %%
data.mean()
# Out:
# <ipython-input-111-abc01cf6c622>:1: FutureWarning: DataFrame.mean and DataFrame.median with numeric_only=None will include datetime64 and datetime64tz columns in a future version.
#   data.mean()
# RPT    12.415559
# VAL    10.106519
# ROS     9.175468
# KIL    10.897985
# SHA     9.439496
# BIR     8.548127
# DUB     8.168874
# CLA     9.240346
# MUL          NaN
# CLO          NaN
# BEL          NaN
# MAL          NaN
# dtype: float64

# %% [markdown]
# <h1>Question-5

# %%
chipo=pd.read_csv("question05.txt",sep='\t')

# %%
chipo.head(10)
# Out:
#    order_id  quantity                              item_name  \
# 0         1         1           Chips and Fresh Tomato Salsa
# 1         1         1                                   Izze
# 2         1         1                       Nantucket Nectar
# 3         1         1  Chips and Tomatillo-Green Chili Salsa
# 4         2         2                           Chicken Bowl
# 5         3         1                           Chicken Bowl
# 6         3         1                          Side of Chips
# 7         4         1                          Steak Burrito
# 8         4         1                       Steak Soft Tacos
# 9         5         1                          Steak Burrito
#
#                                   choice_description item_price
# 0                                                NaN     $2.39
# 1                                       [Clementine]     $3.39
# 2                                            [Apple]     $3.39
# ...

# %%
chipo.count()
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
len(chipo.columns)
# Out:
# 5

# %%
print(chipo.columns)
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
chipo.groupby('item_name')['quantity'].count()
#Chicken Bowl was the most-ordered item
# 726 Chicken Bowl were ordered.
# Out:
# item_name
# 6 Pack Soft Drink                         54
# Barbacoa Bowl                             66
# Barbacoa Burrito                          91
# Barbacoa Crispy Tacos                     11
# Barbacoa Salad Bowl                       10
# Barbacoa Soft Tacos                       25
# Bottled Water                            162
# Bowl                                       2
# Burrito                                    6
# Canned Soda                              104
# Canned Soft Drink                        301
# Carnitas Bowl                             68
# Carnitas Burrito                          59
# Carnitas Crispy Tacos                      7
# Carnitas Salad                             1
# Carnitas Salad Bowl                        6
# Carnitas Soft Tacos                       40
# Chicken Bowl                             726
# Chicken Burrito                          553
# Chicken Crispy Tacos                      47
# Chicken Salad                              9
# ...

# %%
chipo['choice_description'].value_counts()
#Diet Coke was the most ordered item in the choice_description.
# Out:
# [Diet Coke]                                                                                                                                            134
# [Coke]                                                                                                                                                 123
# [Sprite]                                                                                                                                                77
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Lettuce]]                                                                                  42
# [Fresh Tomato Salsa, [Rice, Black Beans, Cheese, Sour Cream, Guacamole, Lettuce]]                                                                       40
#                                                                                                                                                       ...
# ...

# %%
chipo['quantity'].count()
#4622 number of items were ordered in total.
# Out:
# 4622

# %%
chipo['item_price']=chipo['item_price'].apply(lambda x :float(x.split()[0]))

# %%
chipo['item_price'].sum
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.sum of 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object>

# %%
chipo.count()
#4622 ordered were made in the period.
# Out:
# order_id              4622
# quantity              4622
# item_name             4622
# choice_description    3376
# item_price            4622
# dtype: int64

# %%
chipo['item_price'].mean()
# Out:
# <bound method NDFrame._add_numeric_operations.<locals>.mean of 0        $2.39
# 1        $3.39
# 2        $3.39
# 3        $2.39
# 4       $16.98
#          ...
# 4617    $11.75
# 4618    $11.75
# 4619    $11.25
# 4620     $8.75
# 4621     $8.75
# Name: item_price, Length: 4622, dtype: object>

# %%
chipo['item_name'].nunique()
# Out:
# 50

# %% [markdown]
# <h1>Question-6

# %%
que6=pd.read_csv('us-marriages-divorces-1867-2014.csv')

# %%
que6.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
lines = que6.plot.line(x='Year', y=['Marriages','Divorces'],title='Number of Marriages and divorces between 1967 to 2004')

# %% [markdown]
# <h1>Question-7

# %%
que7=pd.read_csv('us-marriages-divorces-1867-2014.csv')

# %%
que7.head()
# Out:
#    Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 0  1867   357000.0   10000.0    36970000                 9.7
# 1  1868   345000.0   10000.0    37885000                 9.1
# 2  1869   348000.0   11000.0    38870000                 9.0
# 3  1870   352000.0   11000.0    39905000                 8.8
# 4  1871   359000.0   12000.0    41010000                 8.8
#
#    Divorces_per_1000
# 0                0.3
# 1                0.3
# 2                0.3
# 3                0.3
# 4                0.3

# %%
updated=que7[que7['Year'].apply(lambda x: x in [1900,1950,2000])]
updated
# Out:
#      Year  Marriages  Divorces  Population  Marriages_per_1000  \
# 33   1900   709000.0   56000.0    76094000                 9.3
# 83   1950  1667000.0  385000.0   151684000                11.0
# 133  2000  2315000.0  944000.0   282398000                 8.2
#
#      Divorces_per_1000
# 33                 0.7
# 83                 2.5
# 133                3.3

# %%
updated.plot.bar(x='Year',y=['Marriages','Divorces'],rot=0,title="Number of marriages and divorces per capita in the U.S.")
plt.ylabel='Numbers'

# %% [markdown]
# <h1>Question-8

# %%
que8=pd.read_csv('actor_kill_counts.csv')

# %%
que8.head()
# Out:
#                    Actor  Count
# 0  Arnold Schwarzenegger    369
# 1           Chow Yun-Fat    295
# 2         Clint Eastwood    207
# 3             Clive Owen    194
# 4         Dolph Lundgren    239

# %%
updated=que8.sort_values(by=['Count'])
updated
# Out:
#                    Actor  Count
# 9          Wesley Snipes    193
# 3             Clive Owen    194
# 5                 Jet Li    201
# 6           Nicolas Cage    204
# 2         Clint Eastwood    207
# 8    Tomisaburo Wakayama    226
# 4         Dolph Lundgren    239
# 7     Sylvester Stallone    267
# 1           Chow Yun-Fat    295
# 0  Arnold Schwarzenegger    369

# %%
updated.plot.barh(x='Actor',y='Count',rot=0,ylabel="Kill Count",title="Compare the deadliest actors in Hollywood")
# Out:
# <AxesSubplot:title={'center':'Compare the deadliest actors in Hollywood'}, ylabel='Actor'>

# %% [markdown]
# <h1>Question-9

# %%
que9=pd.read_csv('roman-emperor-reigns.csv')

# %%
que9.head()
# Out:
#     Emperor  Length_of_Reign         Cause_of_Death
# 0  Augustus            40.58  Possibly assassinated
# 1  Tiberius            22.50  Possibly assassinated
# 2  Caligula             4.83           Assassinated
# 3  Claudius            13.75  Possibly assassinated
# 4      Nero            13.67                Suicide

# %%
updated=que9.drop(columns='Length_of_Reign')

# %%
count=updated.groupby('Cause_of_Death').count()
count
# Out:
#                        Emperor
# Cause_of_Death
# Assassinated                22
# Died in captivity            1
# Executed                     3
# Illness                      5
# Killed in battle             8
# Natural causes              16
# Possibly assassinated        8
# Suicide                      5

# %%
count.plot.pie(y='Emperor', figsize=(12,12),autopct='%1.1f%%')
# Out:
# <AxesSubplot:ylabel='Emperor'>

# %% [markdown]
# <h1>Question-10

# %%
que10=pd.read_csv("arcade-revenue-vs-cs-doctorates.csv")
que10
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
# 5  2005                            1.435
# 6  2006                            1.601
# 7  2007                            1.654
# 8  2008                            1.803
# 9  2009                            1.734
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948
# 5                                      1129
# 6                                      1453
# 7                                      1656
# 8                                      1787
# 9                                      1611

# %%
que10.head()
# Out:
#    Year  Total Arcade Revenue (billions)  \
# 0  2000                            1.196
# 1  2001                            1.176
# 2  2002                            1.269
# 3  2003                            1.240
# 4  2004                            1.307
#
#    Computer Science Doctorates Awarded (US)
# 0                                       861
# 1                                       830
# 2                                       809
# 3                                       867
# 4                                       948

# %%
draw=que10.plot.scatter(x='Total Arcade Revenue (billions)',y='Computer Science Doctorates Awarded (US)',c='Year',
...                       colormap='viridis',figsize=(8,6))
